# %%
# Dependencies
import requests
import json

import requests
import gmaps
import os
import pandas as pd

# %%
L = open("airports.json")
data = json.load(L)

# %%
activities_df = pd.DataFrame(columns = ['Attraction Name', 'Price Level', 'Rating', 'Address', 'City Code'])
  
print(activities_df)
# Out:
# Empty DataFrame
# Columns: [Attraction Name, Price Level, Rating, Address, City Code]
# Index: []

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {"radius": 100000,
    "type": "museum",
    "key": "your key here"}
i=0
j=0
for i in range(len(data)):
    
    #get coords from df
    lat = data[i][0]["latitudeAirport"]
    lng = data[i][0]["longitudeAirport"]
    
    #puts our lat and lngs into our location parameter, this is inside our loop because it is changing
    params["location"] = f"{lat},{lng}"
    
    #get results
    print(f"Retrieving results for index {i} : {data[i][0]['codeIataAirport']}")
    response = requests.get(base_url, params=params).json()
    results = response['results']
    #city_code = data[i][0]['codeIataCity']
    print(data[i][0]['codeIataCity'])
    try:
        #printing our results
        
        #print(results[0])
        for j in range(5):
            #print(results[j]['name'])
            #print(results[j]['rating'])
            #print(results[j]['vicinity'])
            name = str(results[j]['name'])
            rating = str(results[j]['rating'])
            vicinity = str(results[j]['vicinity'])
            price = str(results[j]['price_level'])
            city_code = data[i][0]['codeIataCity']
            print(results[j])
            #print(city_code)
            activities_df = activities_df.append({'Attraction Name': name, 'Price Level': price, 'Rating': rating, 'Address': vicinity, 'City Code': city_code}, ignore_index = True)
    except (KeyError, IndexError):
        #printing our result if we dont have a hotel within 5000m
        print("Missing field/result... skipping.")
        print("-------------")
    
    i += 1
# Out:
# Retrieving results for index 0 : ABQ
# ABQ
# Missing field/result... skipping.
# -------------
# Retrieving results for index 1 : ATL
# ATL
# Missing field/result... skipping.
# -------------
# Retrieving results for index 2 : BWI
# BWI
# Missing field/result... skipping.
# -------------
# Retrieving results for index 3 : BOS
# BOS
# Missing field/result... skipping.
# -------------
# Retrieving results for index 4 : CUN
# CUN
# Missing field/result... skipping.
# -------------
# Retrieving results for index 5 : CLT
# CLT
# Missing field/result... skipping.
# -------------
# Retrieving results for index 6 : ORD
# CHI
# Missing field/result... skipping.
# -------------
# Retrieving results for index 7 : MDW
# CHI
# Missing field/result... skipping.
# -------------
# Retrieving results for index 8 : COS
# COS
# Missing field/result... skipping.
# -------------
# Retrieving results for index 9 : DAL
# DFW
# Missing field/result... skipping.
# -------------
# Retrieving results for index 10 : DFW
# DFW
# Missing field/result... skipping.
# -------------
# Retrieving results for index 11 : DEN
# DEN
# Missing field/result... skipping.
# -------------
# Retrieving results for index 12 : DTW
# DTT
# Missing field/result... skipping.
# -------------
# Retrieving results for index 13 : ELP
# ELP
# Missing field/result... skipping.
# -------------
# Retrieving results for index 14 : GDL
# GDL
# Missing field/result... skipping.
# -------------
# Retrieving results for index 15 : IAH
# HOU
# Missing field/result... skipping.
# -------------
# Retrieving results for index 16 : HOU
# HOU
# Missing field/result... skipping.
# -------------
# Retrieving results for index 17 : MCI
# MKC
# Missing field/result... skipping.
# -------------
# Retrieving results for index 18 : LAS
# LAS
# Missing field/result... skipping.
# -------------
# Retrieving results for index 19 : BJX
# BJX
# Missing field/result... skipping.
# -------------
# Retrieving results for index 20 : LAX
# LAX
# Missing field/result... skipping.
# -------------
# Retrieving results for index 21 : MEX
# MEX
# Missing field/result... skipping.
# -------------
# Retrieving results for index 22 : MIA
# MIA
# Missing field/result... skipping.
# -------------
# Retrieving results for index 23 : MSP
# MSP
# Missing field/result... skipping.
# -------------
# Retrieving results for index 24 : MTY
# MTY
# Missing field/result... skipping.
# -------------
# Retrieving results for index 25 : BNA
# BNA
# Missing field/result... skipping.
# -------------
# Retrieving results for index 26 : MSY
# MSY
# Missing field/result... skipping.
# -------------
# Retrieving results for index 27 : JFK
# NYC
# Missing field/result... skipping.
# -------------
# Retrieving results for index 28 : EWR
# NYC
# Missing field/result... skipping.
# -------------
# Retrieving results for index 29 : OKC
# OKC
# Missing field/result... skipping.
# -------------
# Retrieving results for index 30 : MCO
# ORL
# Missing field/result... skipping.
# -------------
# Retrieving results for index 31 : PHL
# PHL
# Missing field/result... skipping.
# -------------
# Retrieving results for index 32 : PHX
# PHX
# Missing field/result... skipping.
# -------------
# Retrieving results for index 33 : SLC
# SLC
# Missing field/result... skipping.
# -------------
# Retrieving results for index 34 : SAN
# SAN
# Missing field/result... skipping.
# -------------
# Retrieving results for index 35 : SFO
# SFO
# Missing field/result... skipping.
# -------------
# Retrieving results for index 36 : SEA
# SEA
# Missing field/result... skipping.
# -------------
# Retrieving results for index 37 : STL
# STL
# Missing field/result... skipping.
# -------------
# Retrieving results for index 38 : TPA
# TPA
# Missing field/result... skipping.
# -------------
# Retrieving results for index 39 : IAD
# WAS
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 38.9109189, 'lng': -77.44420749999999}, 'viewport': {'northeast': {'lat': 38.91795779999999, 'lng': -77.43572395000001}, 'southwest': {'lat': 38.9085726, 'lng': -77.44703535}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png', 'icon_background_color': '#13B5C7', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/museum_pinlet', 'name': 'Steven F. Udvar-Hazy Center', 'opening_hours': {'open_now': True}, 'photos': [{'height': 8130, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108104018242672248413">Jeff Kirchoff (Jeff)</a>'], 'photo_reference': 'AcYSjRiOBgL7jliowjRBSEx5QHQeoSVsaNYwqH6on0uc6CjM00QXQ-LC2MGqeITYFkHjPT_lHETK7touLRx_sWVCCKuOC35mhdoIcUTYjKQ8vVsPTvI5R4-EI13GHpd3i3mMEXEV7X7GuI0I3IE8gT4-SdoM_3ZcbfDrJ0N7l8yWROtMTi0D', 'width': 12000}], 'place_id': 'ChIJcyBkMutGtokRqMoMaOdxXrE', 'plus_code': {'compound_code': 'WH64+98 Chantilly, VA, USA', 'global_code': '87C4WH64+98'}, 'price_level': 0, 'rating': 4.9, 'reference': 'ChIJcyBkMutGtokRqMoMaOdxXrE', 'scope': 'GOOGLE', 'types': ['museum', 'tourist_attraction', 'point_of_interest', 'establishment'], 'user_ratings_total': 19916, 'vicinity': '14390 Air and Space Museum Parkway, Chantilly'}
# Missing field/result... skipping.
# -------------
# C:\Users\Owner\AppData\Local\Temp\ipykernel_21436\2294458366.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   activities_df = activities_df.append({'Attraction Name': name, 'Price Level': price, 'Rating': rating, 'Address': vicinity, 'City Code': city_code}, ignore_index = True)

# %%
activities_df
# Out:
#                Attraction Name Price Level Rating  \
# 0              Seaport Village           2    4.6
# 1  Steven F. Udvar-Hazy Center           0    4.9
# 2  Steven F. Udvar-Hazy Center           0    4.9
# 3  Steven F. Udvar-Hazy Center           0    4.9
# 4  Steven F. Udvar-Hazy Center           0    4.9
# 5  Steven F. Udvar-Hazy Center           0    4.9
# 6  Steven F. Udvar-Hazy Center           0    4.9
#
#                                          Address City Code
# 0               849 West Harbor Drive, San Diego       SAN
# 1  14390 Air and Space Museum Parkway, Chantilly       WAS
# 2  14390 Air and Space Museum Parkway, Chantilly       WAS
# 3  14390 Air and Space Museum Parkway, Chantilly       WAS
# 4  14390 Air and Space Museum Parkway, Chantilly       WAS
# 5  14390 Air and Space Museum Parkway, Chantilly       WAS
# 6  14390 Air and Space Museum Parkway, Chantilly       WAS
